# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import pandas as pd
from scipy.stats import ttest_ind
from subprocess import check_output
a = pd.read_csv("HR_Employee_Attrition_Data.csv")
a
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 2935   36        No  Travel_Frequently        884  Research & Development
# 2936   39        No      Travel_Rarely        613  Research & Development
# 2937   27        No      Travel_Rarely        155  Research & Development
# 2938   49        No  Travel_Frequently       1023                   Sales
# 2939   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
a[a.isnull()]
# Out:
#       Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0     NaN       NaN            NaN        NaN        NaN               NaN
# 1     NaN       NaN            NaN        NaN        NaN               NaN
# 2     NaN       NaN            NaN        NaN        NaN               NaN
# 3     NaN       NaN            NaN        NaN        NaN               NaN
# 4     NaN       NaN            NaN        NaN        NaN               NaN
# ...   ...       ...            ...        ...        ...               ...
# 2935  NaN       NaN            NaN        NaN        NaN               NaN
# 2936  NaN       NaN            NaN        NaN        NaN               NaN
# 2937  NaN       NaN            NaN        NaN        NaN               NaN
# 2938  NaN       NaN            NaN        NaN        NaN               NaN
# 2939  NaN       NaN            NaN        NaN        NaN               NaN
#
# ...

# %% [markdown]
# # Info details

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2940 entries, 0 to 2939
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       2940 non-null   int64
#  1   Attrition                 2940 non-null   object
#  2   BusinessTravel            2940 non-null   object
#  3   DailyRate                 2940 non-null   int64
#  4   Department                2940 non-null   object
#  5   DistanceFromHome          2940 non-null   int64
#  6   Education                 2940 non-null   int64
#  7   EducationField            2940 non-null   object
#  8   EmployeeCount             2940 non-null   int64
#  9   EmployeeNumber            2940 non-null   int64
#  10  EnvironmentSatisfaction   2940 non-null   int64
#  11  Gender                    2940 non-null   object
#  12  HourlyRate                2940 non-null   int64
#  13  JobInvolvement            2940 non-null   int64
# ...

# %% [markdown]
# # Excel sheet description

# %%
a.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  2940.000000  2940.000000       2940.000000  2940.000000         2940.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.133819   403.440447          8.105485     1.023991            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     2940.000000              2940.000000  2940.000000     2940.000000
# mean      1470.500000                 2.721769    65.891156        2.729932
# ...

# %%
a['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
sns.distplot(a['DailyRate'])

# %%
# Most of the travel happening for the daily rate is 500 and 1250
# Out:
#   File "<ipython-input-9-601c5c91ddb2>", line 1
#     Most of the travel happening for the daily rate is 500 and 1250
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Find out the relation between DistanceFromHome vs DailyRate with respect to Travel_Frequently

# %%
DailyvsDist = a[a['BusinessTravel'] == 'Travel_Frequently']

# %%
DailyvsDist.plot.scatter(x= 'DistanceFromHome',y = 'DailyRate', ylim = (0,2000))

# %%
sns.distplot(DailyvsDist["DailyRate"])

# %%
f, ax = plt.subplots(figsize = (8,6))
fig = sns.boxplot(x = "DistanceFromHome", y = "DailyRate", data = DailyvsDist)
fig.axis(ymin=0,ymax=2000)
# Out:
# (-0.5, 28.5, 0, 2000)

# %%
ttest_ind(DailyvsDist['DistanceFromHome'],DailyvsDist['DailyRate'],equal_var=False)
# Out:
# Ttest_indResult(statistic=-48.262451280553805, pvalue=1.6795705762847084e-200)

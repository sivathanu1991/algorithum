# %%
import pandas as pd
a = pd.read_csv("netflix.csv")
a[(a.release_year == 2019) & (a.type == 'TV Show')]
# Out:
#        show_id     type                       title director  \
# 34    80221550  TV Show  Archibald's Next Big Thing      NaN
# 39    80178151  TV Show                     The Spy      NaN
# 99    80225885  TV Show               Bard of Blood      NaN
# 101   80218107  TV Show      Dragons: Rescue Riders      NaN
# 103   80220715  TV Show                    Skylines      NaN
# ...        ...      ...                         ...      ...
# 6198  80189829  TV Show               The Protector      NaN
# 6204  80091341  TV Show                      Cuckoo      NaN
# 6206  80173174  TV Show                   Samantha!      NaN
# 6215  80066227  TV Show         Crazy Ex-Girlfriend      NaN
# 6219  80186475  TV Show          Pokémon the Series      NaN
#
#                                                    cast         country  \
# 34    Tony Hale, Rosamund Pike, Jordan Fisher, Chels...             NaN
# 39    Sacha Baron Cohen, Noah Emmerich, Hadar Ratzon...          France
# ...

# %%
a[(a.type == 'Movie') & (a.release_year.isin([2018,2019,2020])) & (a.country == 'India')]['rating'].unique()
# Out:
# array(['TV-MA', 'TV-14', 'TV-PG', 'TV-Y7', 'TV-G', 'PG-13', 'TV-Y7-FV'],
#       dtype=object)

# %%
a[a.country == 'United States']
# Out:
#        show_id     type                             title          director  \
# 2     70234439  TV Show                Transformers Prime               NaN
# 3     80058654  TV Show  Transformers: Robots in Disguise               NaN
# 4     80125979    Movie                      #realityhigh  Fernando Lebrija
# 8     80117902  TV Show                      Fire Chasers               NaN
# 20    80060297    Movie                 Manhattan Romance       Tom O'Brien
# ...        ...      ...                               ...               ...
# 6225  70153412  TV Show                           Frasier               NaN
# 6226  70243132  TV Show               La Familia P. Luche               NaN
# 6229  80000063  TV Show                      Red vs. Blue               NaN
# 6230  70286564  TV Show                             Maron               NaN
# 6233  70153404  TV Show                           Friends               NaN
#
# ...

# %%
a[(a.rating == 'R') & (a.release_year == 2019)]
# Out:
#        show_id   type                                       title  \
# 87    80200087  Movie                                      Domino
# 125   81053953  Movie                     Inside Man: Most Wanted
# 529   80182014  Movie                         Dolemite Is My Name
# 654   80994011  Movie                              The Laundromat
# 1038  81053961  Movie                        Undercover Brother 2
# 1100  80175798  Movie                                The Irishman
# 1264  80244457  Movie                             Earthquake Bird
# 1419  80182016  Movie                                    The King
# 1625  81028570  Movie  Extremely Wicked, Shockingly Evil and Vile
# 1773  81053958  Movie                                 Backdraft 2
# 1807  80194950  Movie                                Wine Country
# 2051  80200571  Movie                              The Highwaymen
# 2239  80192187  Movie                             Triple Frontier
# ...

# %%
a.drop(columns = 'show_id')
# Out:
#          type                                        title  \
# 0       Movie      Norm of the North: King Sized Adventure
# 1       Movie                   Jandino: Whatever it Takes
# 2     TV Show                           Transformers Prime
# 3     TV Show             Transformers: Robots in Disguise
# 4       Movie                                 #realityhigh
# ...       ...                                          ...
# 6229  TV Show                                 Red vs. Blue
# 6230  TV Show                                        Maron
# 6231    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4             Fernando Lebrija
# ...                        ...
# ...

# %%
a.duration.unique()
# Out:
# array(['90 min', '94 min', '1 Season', '99 min', '110 min', '60 min',
#        '78 min', '95 min', '58 min', '62 min', '65 min', '61 min',
#        '135 min', '98 min', '96 min', '79 min', '113 min', '80 min',
#        '77 min', '112 min', '106 min', '102 min', '114 min', '125 min',
#        '142 min', '133 min', '100 min', '86 min', '146 min', '10 min',
#        '122 min', '126 min', '116 min', '130 min', '70 min', '128 min',
#        '88 min', '108 min', '93 min', '64 min', '107 min', '92 min',
#        '111 min', '103 min', '40 min', '85 min', '72 min', '45 min',
#        '89 min', '24 min', '127 min', '163 min', '117 min', '42 min',
#        '104 min', '75 min', '82 min', '38 min', '97 min', '81 min',
#        '91 min', '152 min', '87 min', '121 min', '101 min', '119 min',
#        '83 min', '182 min', '124 min', '63 min', '139 min', '171 min',
#        '84 min', '69 min', '76 min', '41 min', '153 min', '141 min',
# ...

# %%
a['duration_min'] = a.duration.apply(lambda x : x.split()[0])
a
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
text = 'geeks for geeks'

# Splits at space 
print(text.split()) 

word = 'geeks, for, geeks'

# Splits at ',' 
print(word.split(',')) 

word = 'geeks:for:geeks'

# Splitting at ':' 
print(word.split(':')) 

word = 'CatBatSatFatOr'

# Splitting at 3 
print([word[i:i+3] for i in range(0, len(word), 3)])
# Out:
# ['geeks', 'for', 'geeks']
# ['geeks', ' for', ' geeks']
# ['geeks', 'for', 'geeks']
# ['Cat', 'Bat', 'Sat', 'Fat', 'Or']

# %%
a.duration.unique()
# Out:
# array(['90 min', '94 min', '1 Season', '99 min', '110 min', '60 min',
#        '78 min', '95 min', '58 min', '62 min', '65 min', '61 min',
#        '135 min', '98 min', '96 min', '79 min', '113 min', '80 min',
#        '77 min', '112 min', '106 min', '102 min', '114 min', '125 min',
#        '142 min', '133 min', '100 min', '86 min', '146 min', '10 min',
#        '122 min', '126 min', '116 min', '130 min', '70 min', '128 min',
#        '88 min', '108 min', '93 min', '64 min', '107 min', '92 min',
#        '111 min', '103 min', '40 min', '85 min', '72 min', '45 min',
#        '89 min', '24 min', '127 min', '163 min', '117 min', '42 min',
#        '104 min', '75 min', '82 min', '38 min', '97 min', '81 min',
#        '91 min', '152 min', '87 min', '121 min', '101 min', '119 min',
#        '83 min', '182 min', '124 min', '63 min', '139 min', '171 min',
#        '84 min', '69 min', '76 min', '41 min', '153 min', '141 min',
# ...

# %%
a
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
b = a.copy()
b
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
a[6232] = 'siva'
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e32762517353> in <module>
# ----> 1 a[6232] = 'siva'
#       2 a
#
# NameError: name 'a' is not defined

# %%
b[b.country == 'India'].country.unique()
# Out:
# array(['India'], dtype=object)

# %%
if we give 'india' as filtering urgument for the column 'country'. It is not taken our urgument , 
which is presenting with
some other urguments. example (United States, India, South Korea, China) show id 81145628
